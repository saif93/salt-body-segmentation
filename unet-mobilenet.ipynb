# %% [markdown]
# # Load Libraries

# %%
import numpy as np
import pandas as pd
import six
from random import randint
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

from sklearn.model_selection import train_test_split

from skimage.transform import resize

import tensorflow as tf
import keras
import keras.callbacks as callbacks
from keras.callbacks import Callback
from keras import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.models import load_model
from keras.optimizers import Adam
from keras.utils.vis_utils import plot_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Dropout,BatchNormalization
from keras.layers import Conv2D, Concatenate, MaxPooling2D
from keras.layers import UpSampling2D, Dropout, BatchNormalization
from tqdm import tqdm_notebook
from keras import initializers
from keras import regularizers
from keras import constraints
from keras.utils import conv_utils
from keras.utils.data_utils import get_file
from keras.engine.topology import get_source_inputs
from keras.engine import InputSpec
from keras import backend as K
from keras.applications.imagenet_utils import _obtain_input_shape
from keras.regularizers import l2
from keras.optimizers import SGD
from keras.losses import binary_crossentropy

from keras.engine.topology import Input
from keras.engine.training import Model
from keras.layers.convolutional import Conv2D, UpSampling2D, Conv2DTranspose
from keras.layers.core import Activation, SpatialDropout2D
from keras.layers.merge import concatenate,add
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D

from keras.preprocessing.image import load_img
from keras import optimizers
from keras.legacy import interfaces
from keras.utils.generic_utils import get_custom_objects
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Params and helpers

# %%
img_size_ori = 101
img_size_target = 128

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# %% [markdown]
# # Loading of training/testing ids and depths
# Reading the training data and the depths, store them in a DataFrame. Also create a test DataFrame with entries from depth not in train.

# %%
train_df = pd.read_csv("../input/tgs-salt-identification-challenge/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/tgs-salt-identification-challenge/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

# %% [markdown]
# # Read images and masks
# Load the images and masks into the DataFrame and divide the pixel values by 255.

# %%
#!unzip /kaggle/input/tgs-salt-identification-challenge/train.zip

# %%
train_df["images"] = [np.array(load_img("/kaggle/working/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
train_df["masks"] = [np.array(load_img("/kaggle/working/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %% [markdown]
# # Calculating the salt coverage and salt coverage classes
# Counting the number of salt pixels in the masks and dividing them by the image size. Also create 11 coverage classes, -0.1 having no salt at all to 1.0 being salt only.
# Plotting the distribution of coverages and coverage classes, and the class against the raw coverage.

# %%
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)

# %%
def cov_to_class(val):    
    for i in range(0, 11):
        if val * 10 <= i :
            return i
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)

# %% [markdown]
# # Show some example images

# %%
max_images = 20
grid_width = 5
grid_height = int(max_images / grid_width)
fig, axs = plt.subplots(grid_height, grid_width, figsize=(grid_width+10, grid_height+5))
for i, idx in enumerate(train_df.index[:max_images]):
    img = train_df.loc[idx].images
    mask = train_df.loc[idx].masks
    ax = axs[int(i / grid_width), i % grid_width]
    ax.imshow(img, cmap="Greys")
    ax.imshow(mask, alpha=0.3, cmap="Greens")
    ax.text(1, img_size_ori-1, train_df.loc[idx].z, color="black")
    ax.text(img_size_ori - 1, 1, round(train_df.loc[idx].coverage, 2), color="black", ha="right", va="top")
    ax.text(1, 1, train_df.loc[idx].coverage_class, color="black", ha="left", va="top")
    ax.set_yticklabels([])
    ax.set_xticklabels([])
plt.suptitle("Green: salt. Top-left: coverage class, top-right: salt coverage, bottom-left: depth")

# %% [markdown]
# # Create train/validation split stratified by salt coverage
# Using the salt coverage as a stratification criterion. Also show an image to check for correct upsampling.

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
    train_df.index.values,
    np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    train_df.coverage.values,
    train_df.z.values,
    test_size=0.2, stratify=train_df.coverage_class, random_state=31)

# %%
tmp_img = np.zeros((img_size_target, img_size_target), dtype=train_df.images.loc[ids_train[10]].dtype)
tmp_img[:img_size_ori, :img_size_ori] = train_df.images.loc[ids_train[10]]
fix, axs = plt.subplots(1, 2, figsize=(15,5))
axs[0].imshow(tmp_img, cmap="Greys")
axs[0].set_title("Original image")
axs[1].imshow(x_train[10].squeeze(), cmap="Greys")
axs[1].set_title("Scaled image")

# %%
# !pip install segmentation-models

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 128, 128, 1)
# (800, 128, 128, 1)

# %%
#Transforming to 3 channels to match the model dimensions
x_train = np.repeat(x_train, 3, axis=-1)
x_valid = np.repeat(x_valid, 3, axis=-1)

# %% [markdown]
# # Metrics

# %%
# https://www.kaggle.com/cpmpml/fast-iou-metric-in-numpy-and-tensorflow
def get_iou_vector(A, B):
    # Numpy version    
    batch_size = A.shape[0]
    metric = 0.0
    for batch in range(batch_size):
        t, p = A[batch], B[batch]
        true = np.sum(t)
        pred = np.sum(p)
        
        # deal with empty mask first
        if true == 0:
            metric += (pred == 0)
            continue
        
        # non empty mask case.  Union is never empty 
        # hence it is safe to divide by its number of pixels
        intersection = np.sum(t * p)
        union = true + pred - intersection
        iou = intersection / union
        
        # iou metrric is a stepwise approximation of the real iou over 0.5
        iou = np.floor(max(0, (iou - 0.45)*20)) / 10
        
        metric += iou
        
    # teake the average over all images in batch
    metric /= batch_size
    return metric


def my_iou_metric(label, pred):
    # Tensorflow version
    return tf.py_func(get_iou_vector, [label, pred > 0.5], tf.float64)

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return score

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

def bce_logdice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - K.log(1. - dice_loss(y_true, y_pred))

# %%
class SnapshotCallbackBuilder:
    def __init__(self, nb_epochs, nb_snapshots, init_lr=0.1):
        self.T = nb_epochs
        self.M = nb_snapshots
        self.alpha_zero = init_lr

    def get_callbacks(self, model_prefix='Model'):

        callback_list = [
            callbacks.ModelCheckpoint("./mobilenet.model",monitor='val_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1),
            swa,
            callbacks.LearningRateScheduler(schedule=self._cosine_anneal_schedule)
        ]

        return callback_list

    def _cosine_anneal_schedule(self, t):
        cos_inner = np.pi * (t % (self.T // self.M))  # t - 1 is used when t has 1-based indexing.
        cos_inner /= self.T // self.M
        cos_out = np.cos(cos_inner) + 1
        return float(self.alpha_zero / 2 * cos_out)

# %%
def l2_norm(grad):
    norm = K.sqrt(K.sum(K.square(grad))) + K.epsilon()
    return norm

class OptimizerWrapper(optimizers.Optimizer):

    def __init__(self, optimizer):     
        
        self.optimizer = optimizers.get(optimizer)

        # patch the `get_gradients` call
        self._optimizer_get_gradients = self.optimizer.get_gradients

    def get_gradients(self, loss, params):      
        grads = self._optimizer_get_gradients(loss, params)
        return grads

    @interfaces.legacy_get_updates_support
    def get_updates(self, loss, params):
        # monkey patch `get_gradients`
        self.optimizer.get_gradients = self.get_gradients

        # get the updates
        self.optimizer.get_updates(loss, params)

        # undo monkey patch
        self.optimizer.get_gradients = self._optimizer_get_gradients

        return self.updates

    def set_weights(self, weights):       
        self.optimizer.set_weights(weights)

    def get_weights(self):        
        return self.optimizer.get_weights()

    def get_config(self):       
        # properties of NormalizedOptimizer
        config = {'optimizer_name': self.optimizer.__class__.__name__.lower()}

        # optimizer config
        optimizer_config = {'optimizer_config': self.optimizer.get_config()}
        return dict(list(optimizer_config.items()) + list(config.items()))

    @property
    def weights(self):
        return self.optimizer.weights

    @property
    def updates(self):
        return self.optimizer.updates

    @classmethod
    def from_config(cls, config):
        raise NotImplementedError

    @classmethod
    def set_normalization_function(cls, name, func):
        global _NORMS
        _NORMS[name] = func

    @classmethod
    def get_normalization_functions(cls):        
        global _NORMS
        return sorted(list(_NORMS.keys()))


class NormalizedOptimizer(OptimizerWrapper):

    def __init__(self, optimizer, normalization='l2'):       
        super(NormalizedOptimizer, self).__init__(optimizer)

        if normalization not in _NORMS:
            raise ValueError('`normalization` must be one of %s.\n' 
                             'Provided was "%s".' % (str(sorted(list(_NORMS.keys()))), normalization))

        self.normalization = normalization
        self.normalization_fn = _NORMS[normalization]
        self.lr = K.variable(1e-3, name='lr')

    def get_gradients(self, loss, params):       
        grads = super(NormalizedOptimizer, self).get_gradients(loss, params)
        grads = [grad / self.normalization_fn(grad) for grad in grads]
        return grads

    def get_config(self):        
        # properties of NormalizedOptimizer
        config = {'normalization': self.normalization}

        # optimizer config
        base_config = super(NormalizedOptimizer, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

    @classmethod
    def from_config(cls, config):       
        optimizer_config = {'class_name': config['optimizer_name'],
                            'config': config['optimizer_config']}

        optimizer = optimizers.get(optimizer_config)
        normalization = config['normalization']

        return cls(optimizer, normalization=normalization)


_NORMS = {
    'l2': l2_norm,
}

# register this optimizer to the global custom objects when it is imported
get_custom_objects().update({'NormalizedOptimizer': NormalizedOptimizer})

# %%
class SWA(keras.callbacks.Callback):
    
    def __init__(self, filepath, swa_epoch):
        super(SWA, self).__init__()
        self.filepath = filepath
        self.swa_epoch = swa_epoch 
    
    def on_train_begin(self, logs=None):
        self.nb_epoch = self.params['epochs']
        print('Stochastic weight averaging selected for last {} epochs.'
              .format(self.nb_epoch - self.swa_epoch))
        
    def on_epoch_end(self, epoch, logs=None):
        
        if epoch == self.swa_epoch:
            self.swa_weights = self.model.get_weights()
            
        elif epoch > self.swa_epoch:    
            for i in range(len(self.swa_weights)):
                self.swa_weights[i] = (self.swa_weights[i] * 
                    (epoch - self.swa_epoch) + self.model.get_weights()[i])/((epoch - self.swa_epoch)  + 1)  

        else:
            pass
        
    def on_train_end(self, logs=None):
        self.model.set_weights(self.swa_weights)
        print('Final model parameters set to stochastic weight average.')
        self.model.save_weights(self.filepath)
        print('Final stochastic averaged weights saved to file.')

# %%
from segmentation_models import Unet
from segmentation_models import get_preprocessing
from tensorflow import layers

BACKBONE = 'efficientnetb7'

# preprocess input
#preprocess_input = get_preprocessing(BACKBONE)


#x_train = preprocess_input(x_train)
#x_valid = preprocess_input(x_valid)

# define model

model = Unet(BACKBONE, encoder_weights='imagenet',input_shape=(128,128,3))

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Dropout, Concatenate, Conv2DTranspose
from keras.applications.mobilenet import MobileNet

def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def decoder_block(inputs, skip, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip])
    x = conv_block(x, num_filters)

    return x

def build_mobilenetv2_unet(input_shape=(128, 128, 3)):
    inputs = Input(shape=input_shape)

    # Pre-trained MobileNet
    encoder = MobileNet(include_top=False, weights='imagenet', input_tensor=inputs)
    #print(encoder.summary())
    # Encoder outputs
    s1 = encoder.get_layer('conv1_relu').output  # Adjust layer names as needed
    s2 = encoder.get_layer('conv_pw_3_relu').output
    s3 = encoder.get_layer('conv_pw_5_relu').output
    s4 = encoder.get_layer('conv_pw_11_relu').output

    # Bridge
    b1 = encoder.get_layer('conv_pw_13_relu').output

    # Decoder
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    d5 = Conv2DTranspose(32, (2, 2), strides=2, padding="same")(d4)

    # Output
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d5)

    model = Model(inputs, outputs, name="MobileNetV2_U-Net")
    return model

# %%
model = build_mobilenetv2_unet()
# Out:
# /opt/conda/lib/python3.6/site-packages/Keras-2.1.5-py3.6.egg/keras/applications/mobilenet.py:224: UserWarning: MobileNet shape is undefined. Weights for input shape (224, 224) will be loaded.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step

# %%
sgd = SGD(0.01, momentum=0.9, nesterov=True)
sgd = NormalizedOptimizer(sgd, normalization='l2')

# %%
model.compile(loss=bce_dice_loss, optimizer=sgd, metrics=[my_iou_metric])

# %%
epochs = 100
snapshot = SnapshotCallbackBuilder(nb_epochs=epochs,nb_snapshots=1,init_lr=1e-3)
batch_size = 32
swa = SWA('./mobilenet.h5',70)
history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=snapshot.get_callbacks(),shuffle=True,verbose=2)
# Out:
# Train on 6400 samples, validate on 800 samples
# Stochastic weight averaging selected for last 30 epochs.
# Epoch 1/100
#  - 38s - loss: 0.5485 - my_iou_metric: 0.5025 - val_loss: 0.6746 - val_my_iou_metric: 0.6484
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.64838, saving model to ./mobilenet.model
# Epoch 2/100
#  - 28s - loss: 0.3771 - my_iou_metric: 0.6609 - val_loss: 0.4147 - val_my_iou_metric: 0.6879
#
# Epoch 00002: val_my_iou_metric improved from 0.64838 to 0.68788, saving model to ./mobilenet.model
# Epoch 3/100
#  - 28s - loss: 0.3218 - my_iou_metric: 0.7021 - val_loss: 0.4419 - val_my_iou_metric: 0.6633
#
# Epoch 00003: val_my_iou_metric did not improve
# Epoch 4/100
#  - 28s - loss: 0.2720 - my_iou_metric: 0.7321 - val_loss: 0.3153 - val_my_iou_metric: 0.7276
#
# Epoch 00004: val_my_iou_metric improved from 0.68788 to 0.72763, saving model to ./mobilenet.model
# Epoch 5/100
#  - 28s - loss: 0.2437 - my_iou_metric: 0.7458 - val_loss: 1.1519 - val_my_iou_metric: 0.6133
#
# Epoch 00005: val_my_iou_metric did not improve
# Epoch 6/100
#  - 28s - loss: 0.2229 - my_iou_metric: 0.7664 - val_loss: 0.3894 - val_my_iou_metric: 0.7230
#
# Epoch 00006: val_my_iou_metric did not improve
# Epoch 7/100
#  - 28s - loss: 0.2033 - my_iou_metric: 0.7739 - val_loss: 0.3148 - val_my_iou_metric: 0.7534
#
# Epoch 00007: val_my_iou_metric improved from 0.72763 to 0.75338, saving model to ./mobilenet.model
# Epoch 8/100
#  - 28s - loss: 0.1747 - my_iou_metric: 0.7834 - val_loss: 0.3185 - val_my_iou_metric: 0.7446
#
# Epoch 00008: val_my_iou_metric did not improve
# Epoch 9/100
#  - 28s - loss: 0.1552 - my_iou_metric: 0.8042 - val_loss: 0.5056 - val_my_iou_metric: 0.7081
#
# Epoch 00009: val_my_iou_metric did not improve
# Epoch 10/100
#  - 28s - loss: 0.1410 - my_iou_metric: 0.8130 - val_loss: 0.3462 - val_my_iou_metric: 0.7782
#
# Epoch 00010: val_my_iou_metric improved from 0.75338 to 0.77825, saving model to ./mobilenet.model
# Epoch 11/100
#  - 28s - loss: 0.1278 - my_iou_metric: 0.8186 - val_loss: 0.3158 - val_my_iou_metric: 0.7054
#
# Epoch 00011: val_my_iou_metric did not improve
# Epoch 12/100
#  - 28s - loss: 0.1203 - my_iou_metric: 0.8272 - val_loss: 0.3278 - val_my_iou_metric: 0.7540
#
# Epoch 00012: val_my_iou_metric did not improve
# Epoch 13/100
#  - 28s - loss: 0.1125 - my_iou_metric: 0.8353 - val_loss: 0.2952 - val_my_iou_metric: 0.7796
#
# Epoch 00013: val_my_iou_metric improved from 0.77825 to 0.77963, saving model to ./mobilenet.model
# Epoch 14/100
#  - 28s - loss: 0.1017 - my_iou_metric: 0.8400 - val_loss: 0.2876 - val_my_iou_metric: 0.7831
#
# Epoch 00014: val_my_iou_metric improved from 0.77963 to 0.78312, saving model to ./mobilenet.model
# Epoch 15/100
#  - 28s - loss: 0.0944 - my_iou_metric: 0.8441 - val_loss: 0.4129 - val_my_iou_metric: 0.7801
#
# Epoch 00015: val_my_iou_metric did not improve
# Epoch 16/100
#  - 28s - loss: 0.0901 - my_iou_metric: 0.8527 - val_loss: 0.3233 - val_my_iou_metric: 0.7581
#
# Epoch 00016: val_my_iou_metric did not improve
# Epoch 17/100
#  - 28s - loss: 0.0835 - my_iou_metric: 0.8527 - val_loss: 0.4761 - val_my_iou_metric: 0.7491
#
# Epoch 00017: val_my_iou_metric did not improve
# Epoch 18/100
#  - 28s - loss: 0.0816 - my_iou_metric: 0.8577 - val_loss: 0.3137 - val_my_iou_metric: 0.7916
#
# Epoch 00018: val_my_iou_metric improved from 0.78312 to 0.79162, saving model to ./mobilenet.model
# Epoch 19/100
#  - 28s - loss: 0.0812 - my_iou_metric: 0.8640 - val_loss: 0.3437 - val_my_iou_metric: 0.7854
#
# Epoch 00019: val_my_iou_metric did not improve
# Epoch 20/100
#  - 28s - loss: 0.0761 - my_iou_metric: 0.8687 - val_loss: 0.3001 - val_my_iou_metric: 0.7804
#
# Epoch 00020: val_my_iou_metric did not improve
# Epoch 21/100
#  - 28s - loss: 0.0791 - my_iou_metric: 0.8683 - val_loss: 0.2691 - val_my_iou_metric: 0.7778
#
# Epoch 00021: val_my_iou_metric did not improve
# Epoch 22/100
#  - 28s - loss: 0.0656 - my_iou_metric: 0.8757 - val_loss: 0.3497 - val_my_iou_metric: 0.7861
#
# Epoch 00022: val_my_iou_metric did not improve
# Epoch 23/100
#  - 28s - loss: 0.0686 - my_iou_metric: 0.8747 - val_loss: 0.3378 - val_my_iou_metric: 0.7975
#
# Epoch 00023: val_my_iou_metric improved from 0.79162 to 0.79750, saving model to ./mobilenet.model
# Epoch 24/100
#  - 28s - loss: 0.0645 - my_iou_metric: 0.8820 - val_loss: 0.4155 - val_my_iou_metric: 0.7919
#
# Epoch 00024: val_my_iou_metric did not improve
# Epoch 25/100
#  - 28s - loss: 0.0597 - my_iou_metric: 0.8829 - val_loss: 0.2976 - val_my_iou_metric: 0.7915
#
# Epoch 00025: val_my_iou_metric did not improve
# Epoch 26/100
#  - 28s - loss: 0.0573 - my_iou_metric: 0.8843 - val_loss: 0.2796 - val_my_iou_metric: 0.7930
#
# Epoch 00026: val_my_iou_metric did not improve
# Epoch 27/100
#  - 28s - loss: 0.0671 - my_iou_metric: 0.8854 - val_loss: 0.2948 - val_my_iou_metric: 0.7950
#
# Epoch 00027: val_my_iou_metric did not improve
# Epoch 28/100
#  - 28s - loss: 0.0526 - my_iou_metric: 0.8925 - val_loss: 0.4016 - val_my_iou_metric: 0.7847
#
# Epoch 00028: val_my_iou_metric did not improve
# Epoch 29/100
#  - 28s - loss: 0.0531 - my_iou_metric: 0.8932 - val_loss: 0.3278 - val_my_iou_metric: 0.7795
#
# Epoch 00029: val_my_iou_metric did not improve
# Epoch 30/100
#  - 28s - loss: 0.0545 - my_iou_metric: 0.8942 - val_loss: 0.2782 - val_my_iou_metric: 0.7669
#
# Epoch 00030: val_my_iou_metric did not improve
# Epoch 31/100
#  - 28s - loss: 0.0518 - my_iou_metric: 0.8976 - val_loss: 0.4769 - val_my_iou_metric: 0.7887
#
# Epoch 00031: val_my_iou_metric did not improve
# Epoch 32/100
#  - 28s - loss: 0.0541 - my_iou_metric: 0.9001 - val_loss: 0.2567 - val_my_iou_metric: 0.7953
#
# Epoch 00032: val_my_iou_metric did not improve
# Epoch 33/100
#  - 28s - loss: 0.0466 - my_iou_metric: 0.9035 - val_loss: 0.3886 - val_my_iou_metric: 0.7952
#
# Epoch 00033: val_my_iou_metric did not improve
# Epoch 34/100
#  - 28s - loss: 0.0474 - my_iou_metric: 0.9043 - val_loss: 0.3797 - val_my_iou_metric: 0.8141
#
# Epoch 00034: val_my_iou_metric improved from 0.79750 to 0.81412, saving model to ./mobilenet.model
# Epoch 35/100
#  - 28s - loss: 0.0483 - my_iou_metric: 0.9045 - val_loss: 0.3280 - val_my_iou_metric: 0.8010
#
# Epoch 00035: val_my_iou_metric did not improve
# Epoch 36/100
#  - 28s - loss: 0.0451 - my_iou_metric: 0.9075 - val_loss: 0.3631 - val_my_iou_metric: 0.7855
#
# Epoch 00036: val_my_iou_metric did not improve
# Epoch 37/100
#  - 28s - loss: 0.0426 - my_iou_metric: 0.9116 - val_loss: 0.4460 - val_my_iou_metric: 0.7949
#
# Epoch 00037: val_my_iou_metric did not improve
# Epoch 38/100
#  - 28s - loss: 0.0412 - my_iou_metric: 0.9137 - val_loss: 0.3513 - val_my_iou_metric: 0.7825
#
# Epoch 00038: val_my_iou_metric did not improve
# Epoch 39/100
#  - 28s - loss: 0.0391 - my_iou_metric: 0.9161 - val_loss: 0.3800 - val_my_iou_metric: 0.8181
#
# Epoch 00039: val_my_iou_metric improved from 0.81412 to 0.81812, saving model to ./mobilenet.model
# Epoch 40/100
#  - 28s - loss: 0.0396 - my_iou_metric: 0.9178 - val_loss: 0.2992 - val_my_iou_metric: 0.7754
#
# Epoch 00040: val_my_iou_metric did not improve
# Epoch 41/100
#  - 28s - loss: 0.0369 - my_iou_metric: 0.9202 - val_loss: 0.2877 - val_my_iou_metric: 0.7820
#
# Epoch 00041: val_my_iou_metric did not improve
# Epoch 42/100
#  - 28s - loss: 0.0370 - my_iou_metric: 0.9224 - val_loss: 0.2617 - val_my_iou_metric: 0.7987
#
# Epoch 00042: val_my_iou_metric did not improve
# Epoch 43/100
#  - 28s - loss: 0.0436 - my_iou_metric: 0.9240 - val_loss: 0.2781 - val_my_iou_metric: 0.7848
#
# Epoch 00043: val_my_iou_metric did not improve
# Epoch 44/100
#  - 28s - loss: 0.0343 - my_iou_metric: 0.9271 - val_loss: 0.3276 - val_my_iou_metric: 0.7881
#
# Epoch 00044: val_my_iou_metric did not improve
# Epoch 45/100
#  - 28s - loss: 0.0320 - my_iou_metric: 0.9280 - val_loss: 0.2879 - val_my_iou_metric: 0.7858
#
# Epoch 00045: val_my_iou_metric did not improve
# Epoch 46/100
#  - 28s - loss: 0.0327 - my_iou_metric: 0.9302 - val_loss: 0.3595 - val_my_iou_metric: 0.7665
#
# Epoch 00046: val_my_iou_metric did not improve
# Epoch 47/100
#  - 28s - loss: 0.0291 - my_iou_metric: 0.9305 - val_loss: 0.4044 - val_my_iou_metric: 0.7985
#
# Epoch 00047: val_my_iou_metric did not improve
# Epoch 48/100
#  - 28s - loss: 0.0323 - my_iou_metric: 0.9321 - val_loss: 0.5448 - val_my_iou_metric: 0.7859
#
# Epoch 00048: val_my_iou_metric did not improve
# Epoch 49/100
#  - 28s - loss: 0.0360 - my_iou_metric: 0.9340 - val_loss: 0.2929 - val_my_iou_metric: 0.7895
#
# Epoch 00049: val_my_iou_metric did not improve
# Epoch 50/100
#  - 28s - loss: 0.0312 - my_iou_metric: 0.9345 - val_loss: 0.3557 - val_my_iou_metric: 0.7920
#
# Epoch 00050: val_my_iou_metric did not improve
# Epoch 51/100
#  - 28s - loss: 0.0299 - my_iou_metric: 0.9362 - val_loss: 0.5563 - val_my_iou_metric: 0.8065
#
# Epoch 00051: val_my_iou_metric did not improve
# Epoch 52/100
#  - 28s - loss: 0.0276 - my_iou_metric: 0.9393 - val_loss: 0.3246 - val_my_iou_metric: 0.8190
#
# Epoch 00052: val_my_iou_metric improved from 0.81812 to 0.81900, saving model to ./mobilenet.model
# Epoch 53/100
#  - 28s - loss: 0.0279 - my_iou_metric: 0.9368 - val_loss: 0.3407 - val_my_iou_metric: 0.8004
#
# Epoch 00053: val_my_iou_metric did not improve
# Epoch 54/100
#  - 28s - loss: 0.0255 - my_iou_metric: 0.9412 - val_loss: 0.5206 - val_my_iou_metric: 0.7812
#
# Epoch 00054: val_my_iou_metric did not improve
# Epoch 55/100
#  - 28s - loss: 0.0253 - my_iou_metric: 0.9424 - val_loss: 0.4649 - val_my_iou_metric: 0.7594
#
# Epoch 00055: val_my_iou_metric did not improve
# Epoch 56/100
#  - 28s - loss: 0.0249 - my_iou_metric: 0.9428 - val_loss: 0.4135 - val_my_iou_metric: 0.7995
#
# Epoch 00056: val_my_iou_metric did not improve
# Epoch 57/100
#  - 28s - loss: 0.0277 - my_iou_metric: 0.9424 - val_loss: 0.3920 - val_my_iou_metric: 0.8031
#
# Epoch 00057: val_my_iou_metric did not improve
# Epoch 58/100
#  - 28s - loss: 0.0268 - my_iou_metric: 0.9435 - val_loss: 0.3691 - val_my_iou_metric: 0.7922
#
# Epoch 00058: val_my_iou_metric did not improve
# Epoch 59/100
#  - 28s - loss: 0.0253 - my_iou_metric: 0.9440 - val_loss: 0.4640 - val_my_iou_metric: 0.8044
#
# Epoch 00059: val_my_iou_metric did not improve
# Epoch 60/100
#  - 28s - loss: 0.0269 - my_iou_metric: 0.9447 - val_loss: 0.5067 - val_my_iou_metric: 0.7915
#
# Epoch 00060: val_my_iou_metric did not improve
# Epoch 61/100
#  - 28s - loss: 0.0304 - my_iou_metric: 0.9447 - val_loss: 0.4680 - val_my_iou_metric: 0.7895
#
# Epoch 00061: val_my_iou_metric did not improve
# Epoch 62/100
#  - 28s - loss: 0.0282 - my_iou_metric: 0.9461 - val_loss: 0.4066 - val_my_iou_metric: 0.7906
#
# Epoch 00062: val_my_iou_metric did not improve
# Epoch 63/100
#  - 28s - loss: 0.0235 - my_iou_metric: 0.9482 - val_loss: 0.3605 - val_my_iou_metric: 0.8037
#
# Epoch 00063: val_my_iou_metric did not improve
# Epoch 64/100
#  - 28s - loss: 0.0609 - my_iou_metric: 0.9380 - val_loss: 0.4634 - val_my_iou_metric: 0.8171
#
# Epoch 00064: val_my_iou_metric did not improve
# Epoch 65/100
#  - 28s - loss: 0.0241 - my_iou_metric: 0.9490 - val_loss: 0.3925 - val_my_iou_metric: 0.8133
#
# Epoch 00065: val_my_iou_metric did not improve
# Epoch 66/100
#  - 28s - loss: 0.0218 - my_iou_metric: 0.9500 - val_loss: 0.4652 - val_my_iou_metric: 0.8104
#
# Epoch 00066: val_my_iou_metric did not improve
# Epoch 67/100
#  - 28s - loss: 0.0247 - my_iou_metric: 0.9500 - val_loss: 0.2926 - val_my_iou_metric: 0.7861
#
# Epoch 00067: val_my_iou_metric did not improve
# Epoch 68/100
#  - 28s - loss: 0.0243 - my_iou_metric: 0.9512 - val_loss: 0.4824 - val_my_iou_metric: 0.8039
#
# Epoch 00068: val_my_iou_metric did not improve
# Epoch 69/100
#  - 28s - loss: 0.0221 - my_iou_metric: 0.9524 - val_loss: 0.2793 - val_my_iou_metric: 0.7687
#
# Epoch 00069: val_my_iou_metric did not improve
# Epoch 70/100
#  - 28s - loss: 0.0243 - my_iou_metric: 0.9526 - val_loss: 0.4775 - val_my_iou_metric: 0.8004
#
# Epoch 00070: val_my_iou_metric did not improve
# Epoch 71/100
#  - 28s - loss: 0.0230 - my_iou_metric: 0.9527 - val_loss: 0.5007 - val_my_iou_metric: 0.8169
#
# Epoch 00071: val_my_iou_metric did not improve
# Epoch 72/100
#  - 28s - loss: 0.0210 - my_iou_metric: 0.9539 - val_loss: 0.3541 - val_my_iou_metric: 0.7794
#
# Epoch 00072: val_my_iou_metric did not improve
# Epoch 73/100
#  - 28s - loss: 0.0253 - my_iou_metric: 0.9526 - val_loss: 0.4763 - val_my_iou_metric: 0.8017
#
# Epoch 00073: val_my_iou_metric did not improve
# Epoch 74/100
#  - 28s - loss: 0.0205 - my_iou_metric: 0.9528 - val_loss: 0.2858 - val_my_iou_metric: 0.7943
#
# Epoch 00074: val_my_iou_metric did not improve
# Epoch 75/100
#  - 28s - loss: 0.0250 - my_iou_metric: 0.9522 - val_loss: 0.5263 - val_my_iou_metric: 0.8025
#
# Epoch 00075: val_my_iou_metric did not improve
# Epoch 76/100
#  - 28s - loss: 0.0204 - my_iou_metric: 0.9536 - val_loss: 0.4276 - val_my_iou_metric: 0.7999
#
# Epoch 00076: val_my_iou_metric did not improve
# Epoch 77/100
#  - 28s - loss: 0.0202 - my_iou_metric: 0.9542 - val_loss: 0.3492 - val_my_iou_metric: 0.7805
#
# Epoch 00077: val_my_iou_metric did not improve
# Epoch 78/100
#  - 28s - loss: 0.0220 - my_iou_metric: 0.9563 - val_loss: 0.5198 - val_my_iou_metric: 0.8117
#
# Epoch 00078: val_my_iou_metric did not improve
# Epoch 79/100
#  - 29s - loss: 0.0295 - my_iou_metric: 0.9530 - val_loss: 0.5351 - val_my_iou_metric: 0.7920
#
# Epoch 00079: val_my_iou_metric did not improve
# Epoch 80/100
#  - 28s - loss: 0.0225 - my_iou_metric: 0.9561 - val_loss: 0.5179 - val_my_iou_metric: 0.8049
#
# Epoch 00080: val_my_iou_metric did not improve
# Epoch 81/100
#  - 28s - loss: 0.0271 - my_iou_metric: 0.9576 - val_loss: 0.3298 - val_my_iou_metric: 0.8050
#
# Epoch 00081: val_my_iou_metric did not improve
# Epoch 82/100
#  - 28s - loss: 0.0216 - my_iou_metric: 0.9560 - val_loss: 0.5004 - val_my_iou_metric: 0.8040
#
# Epoch 00082: val_my_iou_metric did not improve
# Epoch 83/100
#  - 29s - loss: 0.0198 - my_iou_metric: 0.9578 - val_loss: 0.4129 - val_my_iou_metric: 0.8072
#
# Epoch 00083: val_my_iou_metric did not improve
# Epoch 84/100
#  - 29s - loss: 0.0190 - my_iou_metric: 0.9593 - val_loss: 0.4849 - val_my_iou_metric: 0.7941
#
# Epoch 00084: val_my_iou_metric did not improve
# Epoch 85/100
#  - 28s - loss: 0.0218 - my_iou_metric: 0.9583 - val_loss: 0.4668 - val_my_iou_metric: 0.8076
#
# Epoch 00085: val_my_iou_metric did not improve
# Epoch 86/100
#  - 28s - loss: 0.0192 - my_iou_metric: 0.9582 - val_loss: 0.5142 - val_my_iou_metric: 0.7869
#
# Epoch 00086: val_my_iou_metric did not improve
# Epoch 87/100
#  - 28s - loss: 0.0217 - my_iou_metric: 0.9590 - val_loss: 0.4506 - val_my_iou_metric: 0.8064
#
# Epoch 00087: val_my_iou_metric did not improve
# Epoch 88/100
#  - 29s - loss: 0.0200 - my_iou_metric: 0.9588 - val_loss: 0.4812 - val_my_iou_metric: 0.8035
#
# Epoch 00088: val_my_iou_metric did not improve
# Epoch 89/100
#  - 27s - loss: 0.0183 - my_iou_metric: 0.9616 - val_loss: 0.5250 - val_my_iou_metric: 0.8058
#
# Epoch 00089: val_my_iou_metric did not improve
# Epoch 90/100
#  - 29s - loss: 0.0219 - my_iou_metric: 0.9599 - val_loss: 0.3856 - val_my_iou_metric: 0.8097
#
# Epoch 00090: val_my_iou_metric did not improve
# Epoch 91/100
#  - 28s - loss: 0.0183 - my_iou_metric: 0.9600 - val_loss: 0.3980 - val_my_iou_metric: 0.8029
#
# Epoch 00091: val_my_iou_metric did not improve
# Epoch 92/100
#  - 28s - loss: 0.0208 - my_iou_metric: 0.9597 - val_loss: 0.5102 - val_my_iou_metric: 0.8160
#
# Epoch 00092: val_my_iou_metric did not improve
# Epoch 93/100
#  - 28s - loss: 0.0205 - my_iou_metric: 0.9602 - val_loss: 0.5467 - val_my_iou_metric: 0.8035
#
# Epoch 00093: val_my_iou_metric did not improve
# Epoch 94/100
#  - 28s - loss: 0.0187 - my_iou_metric: 0.9621 - val_loss: 0.5425 - val_my_iou_metric: 0.8054
#
# Epoch 00094: val_my_iou_metric did not improve
# Epoch 95/100
#  - 28s - loss: 0.0183 - my_iou_metric: 0.9629 - val_loss: 0.5245 - val_my_iou_metric: 0.8091
#
# Epoch 00095: val_my_iou_metric did not improve
# Epoch 96/100
#  - 28s - loss: 0.0184 - my_iou_metric: 0.9628 - val_loss: 0.5136 - val_my_iou_metric: 0.8047
#
# Epoch 00096: val_my_iou_metric did not improve
# Epoch 97/100
#  - 28s - loss: 0.0202 - my_iou_metric: 0.9610 - val_loss: 0.4087 - val_my_iou_metric: 0.7979
#
# Epoch 00097: val_my_iou_metric did not improve
# Epoch 98/100
#  - 28s - loss: 0.0192 - my_iou_metric: 0.9625 - val_loss: 0.3631 - val_my_iou_metric: 0.8122
#
# Epoch 00098: val_my_iou_metric did not improve
# Epoch 99/100
#  - 29s - loss: 0.0177 - my_iou_metric: 0.9639 - val_loss: 0.3988 - val_my_iou_metric: 0.7997
#
# Epoch 00099: val_my_iou_metric did not improve
# Epoch 100/100
#  - 28s - loss: 0.0198 - my_iou_metric: 0.9630 - val_loss: 0.3806 - val_my_iou_metric: 0.8144
#
# Epoch 00100: val_my_iou_metric did not improve
# Final model parameters set to stochastic weight average.
# Final stochastic averaged weights saved to file.

# %%
# Load best model
try:
    
    model.load_weights('./mobilenet.h5')
    print('using swa weight model')
except:
    model.load_weights('./mobilenet.model')
# Out:
# using swa weight model

# %%
def predict_result(model,x_test,img_size_target,batch_size): # predict both orginal and reflect x
    x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
    preds_test1 = model.predict([x_test],batch_size=batch_size).reshape(-1, img_size_target, img_size_target)
    preds_test2_refect = model.predict([x_test_reflect],batch_size=batch_size).reshape(-1, img_size_target, img_size_target)
    preds_test2 = np.array([ np.fliplr(x) for x in preds_test2_refect] )
    preds_avg = (preds_test1 +preds_test2)/2
    return preds_avg

# %%
preds_valid = predict_result(model,x_valid,img_size_target,batch_size)
preds_valid = np.array([downsample(x) for x in preds_valid])
y_valid_ori = np.array([downsample(x) for x in y_valid])

# %%
max_images = 20
grid_width = 5
grid_height = int(max_images / grid_width)
fig, axs = plt.subplots(grid_height, grid_width, figsize=(grid_width+10, grid_height+5))
for i, idx in enumerate(ids_valid[:max_images]):
    img = x_valid[i]
    mask = y_valid[i].squeeze()
    pred = preds_valid[i]
    ax = axs[int(i / grid_width), i % grid_width]
    ax.imshow(img, cmap="Greys")
    ax.imshow(mask, alpha=0.3, cmap="Greens")
    ax.imshow(pred, alpha=0.3, cmap="OrRd")
plt.suptitle("Green: salt, Red: prediction. Top-left: coverage class, top-right: salt coverage, bottom-left: depth")
# Out:
# Text(0.5,0.98,'Green: salt, Red: prediction. Top-left: coverage class, top-right: salt coverage, bottom-left: depth')

# %%
# src: https://www.kaggle.com/aglotero/another-iou-metric
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in
    
    true_objects = 2
    pred_objects = 2

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    # Compute areas (needed for finding the union between all objects)
    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection

    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
## Scoring for last model
thresholds = np.linspace(0.3, 0.7, 31)
ious = np.array([iou_metric_batch(y_valid_ori, np.int32(preds_valid > threshold)) for threshold in tqdm_notebook(thresholds)])
# Out:
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))

# %%
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

def calculate_metrics(preds_valid, y_valid_ori, threshold=0.5):
  """Calculates precision, recall, F1-score, and accuracy for binary classification.

  Args:
    preds_valid: Predicted probabilities.
    y_valid_ori: Original probability maps.
    threshold: Threshold for binarizing predictions.

  Returns:
    A tuple of precision, recall, F1-score, and accuracy.
  """

  y_valid_bin = np.where(y_valid_ori > threshold, 1, 0)
  y_valid_flat = y_valid_bin.flatten()
  preds_valid_bin_flat = (preds_valid > threshold).astype(np.uint8).flatten()

  precision = precision_score(y_valid_flat, preds_valid_bin_flat)
  recall = recall_score(y_valid_flat, preds_valid_bin_flat)
  f1 = f1_score(y_valid_flat, preds_valid_bin_flat)
  accuracy = accuracy_score(y_valid_flat, preds_valid_bin_flat)

  print("Precision:", precision)
  print("Recall:", recall)
  print("F1-score:", f1)
  print("Accuracy:", accuracy)

  return precision, recall, f1, accuracy

# %%
calculate_metrics(preds_valid, y_valid_ori)
# Out:
# Precision: 0.9597913554716918
# Recall: 0.9097531708971588
# F1-score: 0.9341026295169196
# Accuracy: 0.96809503970199
# (0.9597913554716918, 0.9097531708971588, 0.9341026295169196, 0.96809503970199)

# %%
model.save('mobilenet.model')

# %%
model.save('mobilenet.h5')

# %%
from IPython.display import FileLink
FileLink(r'mobilenet.h5')
# Out:
# /kaggle/working/mobilenet.h5
